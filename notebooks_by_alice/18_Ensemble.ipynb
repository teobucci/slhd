# %% [markdown]
# # Classification: Ensemble

# %% [markdown]
# ## Data import

# %%
import pandas as pd
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      timespreg  gluctol  diaspb  triceps  insulin  massindex  pedigree  age  \
# 0            6      148      72       35        0       33.6     0.627   50
# 1            1       85      66       29        0       26.6     0.351   31
# 2            8      183      64        0        0       23.3     0.672   32
# 3            1       89      66       23       94       28.1     0.167   21
# 4            0      137      40       35      168       43.1     2.288   33
# ..         ...      ...     ...      ...      ...        ...       ...  ...
# 763         10      101      76       48      180       32.9     0.171   63
# 764          2      122      70       27        0       36.8     0.340   27
# 765          5      121      72       23      112       26.2     0.245   30
# 766          1      126      60        0        0       30.1     0.349   47
# 767          1       93      70       31        0       30.4     0.315   23
#
#      target
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
# ..      ...
# 763       0
# 764       0
# 765       0
# 766       1
# 767       0
#
# [768 rows x 9 columns]

# %%
#Print class freq. through pandas 
print(df.groupby('target').size())

#some imports to plot 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

#Visualize Class Counts
sns.countplot(y=df.target ,data=df)
plt.xlabel("count of each class")
plt.ylabel("classes")
plt.show()
# Out:
# target
# 0    500
# 1    268
# dtype: int64

# %%
#gives information about the data types,columns, null value counts, memory usage etc
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timespreg  768 non-null    int64
#  1   gluctol    768 non-null    int64
#  2   diaspb     768 non-null    int64
#  3   triceps    768 non-null    int64
#  4   insulin    768 non-null    int64
#  5   massindex  768 non-null    float64
#  6   pedigree   768 non-null    float64
#  7   age        768 non-null    int64
#  8   target     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Separate Train/Test sets

# %%
#Separate X and y (explanatory variables and target variable)
X = df.iloc[:,0:-1]
y = df.iloc[:,-1] #[-1]]

#X.head()
#y.head()

# %%
from sklearn.model_selection import train_test_split

#SPLIT DATA INTO TRAIN AND TEST SET
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size =0.30, #by default is 75%-25%
                                                    #shuffle is set True by default,
                                                    stratify=y, #preserve target propotions 
                                                    random_state= 123) #fix random seed for replicability

print(X_train.shape, X_test.shape)
# Out:
# (537, 8) (231, 8)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ![RF](rf.png)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

classifier= RandomForestClassifier()
parameters = {'n_estimators' : [50, 100, 200],
    'criterion' : ['entropy', 'gini'],
             'max_depth' : [1,2,3,4], 
             'min_samples_split' : [4,5,10],
              'min_samples_leaf' : [4,5,10]
             }

gs = GridSearchCV(classifier, parameters, cv=3, scoring = 'f1', verbose=10, n_jobs=-1, refit=True)

gs.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [1, 2, 3, 4],
#                          'min_samples_leaf': [4, 5, 10],
#                          'min_samples_split': [4, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='f1', verbose=10)

# %%
#summarize the results of your GRIDSEARCH
print('***GRIDSEARCH RESULTS***')

print("Best score: %f using %s" % (gs.best_score_, gs.best_params_))
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
params = gs.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ***GRIDSEARCH RESULTS***
# Best score: 0.592155 using {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.242239 (0.145804) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.274081 (0.143688) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.226468 (0.076485) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.179967 (0.109005) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.152155 (0.077109) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.138337 (0.112315) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.293091 (0.165311) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.207733 (0.084138) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.195945 (0.109241) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.172158 (0.125843) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.192654 (0.137081) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.213547 (0.156433) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.273555 (0.054104) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.184018 (0.095087) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.249233 (0.134577) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.314614 (0.141340) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.192063 (0.165886) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.257517 (0.119570) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.172668 (0.096183) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.205893 (0.102498) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.218044 (0.126115) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.232890 (0.121762) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.193266 (0.074617) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.181588 (0.106876) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.269386 (0.031177) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.238204 (0.095670) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.184018 (0.095087) with: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.513804 (0.048264) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.507624 (0.054743) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.518844 (0.053643) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.543007 (0.048256) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.517524 (0.057737) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.502702 (0.071108) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.523730 (0.051321) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.484645 (0.029547) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.529435 (0.044405) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.535991 (0.044040) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.496812 (0.042651) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.508154 (0.031134) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.495601 (0.045564) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.509972 (0.030809) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.509574 (0.042988) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.511803 (0.030957) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.498935 (0.054008) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.520558 (0.042950) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.506810 (0.029712) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.507529 (0.063584) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.502034 (0.048558) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.526324 (0.047120) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.528088 (0.059454) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.512072 (0.032191) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.509086 (0.054305) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.504355 (0.036649) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.498343 (0.044297) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.542296 (0.045517) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.565227 (0.055290) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.554853 (0.054849) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.545820 (0.051409) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.552447 (0.046955) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.552324 (0.052379) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.574728 (0.065275) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.552375 (0.053393) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.546793 (0.045454) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.556658 (0.032678) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.562370 (0.039930) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.566948 (0.059249) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.539341 (0.047918) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.546508 (0.058168) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.554076 (0.049901) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.540407 (0.044168) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.552857 (0.048689) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.553329 (0.049365) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.544261 (0.050771) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.550401 (0.059227) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.554076 (0.049901) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.556263 (0.066842) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.537230 (0.050561) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.557898 (0.052892) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.552381 (0.060734) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.556447 (0.057952) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.558785 (0.056989) with: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.578741 (0.058685) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.573609 (0.045121) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.568808 (0.035088) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.568669 (0.066002) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.580476 (0.042509) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.575902 (0.053787) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.558560 (0.089184) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.572122 (0.037137) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.577447 (0.047565) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.549229 (0.064651) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.575729 (0.049993) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.555620 (0.046957) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.579688 (0.076501) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.564123 (0.073239) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.580963 (0.045709) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.580647 (0.053420) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.589086 (0.046432) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.565092 (0.038848) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.571198 (0.039418) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.586396 (0.050027) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.566365 (0.058169) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.560569 (0.058703) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.568282 (0.059451) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.583848 (0.055721) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.583476 (0.048372) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.578776 (0.061117) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.572104 (0.051638) with: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.278933 (0.059207) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.252739 (0.134166) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.191470 (0.123790) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.248354 (0.176574) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.283660 (0.120503) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.289652 (0.132259) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.329190 (0.053461) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.193248 (0.058754) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.243904 (0.108417) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.344447 (0.005112) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.244771 (0.128728) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.217771 (0.078563) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.251957 (0.057718) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.297160 (0.036180) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.234397 (0.068622) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.172083 (0.096510) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.299221 (0.029281) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.294245 (0.070658) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.271903 (0.128148) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.186283 (0.099450) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.227834 (0.114159) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.238095 (0.178174) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.332346 (0.031458) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.243698 (0.049151) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.245450 (0.102460) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.280566 (0.093597) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.231977 (0.100031) with: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.507979 (0.033080) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.538089 (0.068058) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.539009 (0.060635) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.510913 (0.058842) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.533410 (0.055778) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.536111 (0.054575) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.511451 (0.054567) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.524980 (0.044860) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.524813 (0.053298) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.512453 (0.050363) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.527558 (0.051977) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.541233 (0.049032) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.506459 (0.057404) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.525374 (0.037815) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.518758 (0.040461) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.509666 (0.042695) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.516494 (0.045838) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.519538 (0.046115) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.503454 (0.047313) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.530556 (0.045176) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.532659 (0.060569) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.526274 (0.034033) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.513607 (0.037355) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.520334 (0.038739) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.512743 (0.045173) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.515323 (0.034444) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.526515 (0.050890) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.530871 (0.037502) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.578850 (0.048926) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.559420 (0.057913) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.547542 (0.030241) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.553159 (0.053036) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.561393 (0.067768) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.551705 (0.072519) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.559697 (0.046691) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.563126 (0.057203) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.564537 (0.050678) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.561325 (0.058740) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.556716 (0.051811) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.542515 (0.042573) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.545951 (0.051924) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.559001 (0.060728) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.568721 (0.052979) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.543147 (0.045894) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.566032 (0.046751) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.555074 (0.059709) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.559547 (0.054210) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.565134 (0.065005) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.562470 (0.052126) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.574861 (0.053605) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.553071 (0.052899) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.552288 (0.037830) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.555576 (0.051914) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.560537 (0.054513) with: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}
# 0.589296 (0.052243) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
# 0.580679 (0.042857) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.573405 (0.048784) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.549913 (0.062379) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50}
# 0.575876 (0.054275) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# 0.584862 (0.045519) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# 0.555808 (0.051592) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50}
# 0.569759 (0.049332) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# 0.575968 (0.050843) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 0.568482 (0.045730) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50}
# 0.573960 (0.048630) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.571699 (0.046282) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.592155 (0.047369) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
# 0.585708 (0.045886) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.570156 (0.046608) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 0.569999 (0.038751) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 50}
# 0.580118 (0.047454) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.576169 (0.050546) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 0.571788 (0.039855) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 50}
# 0.556267 (0.048048) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 100}
# 0.563303 (0.059787) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 200}
# 0.578396 (0.060418) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0.566646 (0.062662) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.550055 (0.059153) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# 0.567038 (0.040070) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0.562543 (0.052663) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.556583 (0.070063) with: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 200}

# %%
#TEST ON YOUR TEST SET 
best_model = gs.best_estimator_
y_pred = best_model.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82       150
#            1       0.70      0.49      0.58        81
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.69      0.70       231
# weighted avg       0.74      0.75      0.74       231

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap="Reds", cbar=False);

# %%
from sklearn.ensemble import RandomForestClassifier

rand_forest = RandomForestClassifier(n_estimators=50, criterion='gini', max_depth=4, min_samples_split=5, min_samples_leaf=4)
rand_forest.fit(X_train, y_train)

y_pred = rand_forest.predict(X_test)

# %%
# ROC curve

from sklearn import metrics

y_probs = rand_forest.predict_proba(X_test) #predict_proba gives the probabilities for the target (0 and 1 in your case) 

fpr, tpr, thresholds=metrics.roc_curve(y_test,  y_probs[:,1])

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

auc = metrics.roc_auc_score(y_test, y_probs[:,1])
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.84

# %%
sns.barplot(x=X_train.columns, y=rand_forest.feature_importances_, palette="Blues_d")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Adaboost

# %% [markdown]
# ![Adab](adab.png)

# %% [markdown]
# error = sum of the weights associated to the incorrectly classified samples. error $\in [0,1]$

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

adaboost = AdaBoostClassifier(n_estimators=1000, base_estimator=DecisionTreeClassifier(max_depth=3))
adaboost.fit(X_train, y_train)

y_pred = adaboost.predict(X_test)

y_pred_train = adaboost.predict(X_test)
print("f1_score: ", metrics.f1_score(y_test, y_pred))
# Out:
# f1_score:  0.6375

# %%
## from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV

classifier= AdaBoostClassifier()
parameters = {'n_estimators' : [2000, 5000],
    'learning_rate' : [0.0001, 0.01, 0.1, 1, 10]}

gs = GridSearchCV(classifier, parameters, cv=3, scoring = 'f1', verbose=10, n_jobs=-1, refit=True)

gs.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.0001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [2000, 5000]},
#              scoring='f1', verbose=10)

# %%
#summarize the results of your GRIDSEARCH
print('***GRIDSEARCH RESULTS***')

print("Best score: %f using %s" % (gs.best_score_, gs.best_params_))
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
params = gs.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ***GRIDSEARCH RESULTS***
# Best score: 0.611641 using {'learning_rate': 0.01, 'n_estimators': 5000}
# 0.567578 (0.061997) with: {'learning_rate': 0.0001, 'n_estimators': 2000}
# 0.510947 (0.023410) with: {'learning_rate': 0.0001, 'n_estimators': 5000}
# 0.607584 (0.051971) with: {'learning_rate': 0.01, 'n_estimators': 2000}
# 0.611641 (0.065904) with: {'learning_rate': 0.01, 'n_estimators': 5000}
# 0.583255 (0.052983) with: {'learning_rate': 0.1, 'n_estimators': 2000}
# 0.574080 (0.051862) with: {'learning_rate': 0.1, 'n_estimators': 5000}
# 0.541041 (0.014021) with: {'learning_rate': 1, 'n_estimators': 2000}
# 0.545870 (0.015748) with: {'learning_rate': 1, 'n_estimators': 5000}
# 0.277418 (0.078891) with: {'learning_rate': 10, 'n_estimators': 2000}
# 0.277418 (0.078891) with: {'learning_rate': 10, 'n_estimators': 5000}

# %%
#TEST ON YOUR TEST SET 
best_model = gs.best_estimator_
y_pred = best_model.predict(X_test)

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap="Reds", cbar=False);

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       150
#            1       0.68      0.59      0.63        81
#
#     accuracy                           0.76       231
#    macro avg       0.73      0.72      0.73       231
# weighted avg       0.75      0.76      0.75       231

# %%
y_pred_train = best_model.predict(X_train)
print("f1_score_train: ", metrics.f1_score(y_train, y_pred_train))
print("f1_score_test: ", metrics.f1_score(y_test, y_pred))
# Out:
# f1_score_train:  0.7383720930232558
# f1_score_test:  0.631578947368421

# %%
adaboost = AdaBoostClassifier(n_estimators=1000, learning_rate=0.01)

adaboost.fit(X_train,y_train)

y_probs = adaboost.predict_proba(X_test) #predict_proba gives the probabilities for the target (0 and 1 in your case) 

fpr, tpr, thresholds=metrics.roc_curve(y_test,  y_probs[:,1])

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

auc = metrics.roc_auc_score(y_test, y_probs[:,1])
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.84
# [CV 3/3; 1/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 3/3; 1/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.247 total time=   0.2s
# [CV 1/3; 4/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 1/3; 4/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.031 total time=   0.2s
# [CV 1/3; 6/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 1/3; 6/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.091 total time=   0.6s
# [CV 3/3; 9/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 3/3; 9/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.197 total time=   0.6s
# [CV 2/3; 14/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 2/3; 14/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.197 total time=   0.3s
# [CV 2/3; 16/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 2/3; 16/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.375 total time=   0.1s
# [CV 1/3; 18/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 1/3; 18/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.091 total time=   0.6s
# [CV 2/3; 22/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 2/3; 22/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.333 total time=   0.2s
# [CV 3/3; 23/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 3/3; 23/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.222 total time=   0.3s
# [CV 3/3; 25/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 25/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.225 total time=   0.2s
# [CV 2/3; 27/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 27/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.293 total time=   0.6s
# [CV 2/3; 31/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/3; 31/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.557 total time=   0.2s
# [CV 1/3; 33/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 1/3; 33/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.571 total time=   0.6s
# [CV 3/3; 36/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 3/3; 36/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.467 total time=   0.6s
# [CV 3/3; 41/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/3; 41/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.472 total time=   0.3s
# [CV 1/3; 44/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 1/3; 44/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.571 total time=   0.3s
# [CV 3/3; 45/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 45/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.462 total time=   0.7s
# [CV 2/3; 51/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 2/3; 51/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.532 total time=   0.6s
# [CV 3/3; 54/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 3/3; 54/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.449 total time=   0.8s
# [CV 1/3; 60/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 1/3; 60/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.588 total time=   0.6s
# [CV 2/3; 64/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 64/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.596 total time=   0.2s
# [CV 1/3; 66/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 1/3; 66/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.615 total time=   0.6s
# [CV 3/3; 69/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 69/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.484 total time=   0.7s
# [CV 3/3; 74/216] START criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 3/3; 74/216] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.467 total time=   0.3s
# [CV 1/3; 77/216] START criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 1/3; 77/216] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.583 total time=   0.3s
# [CV 1/3; 79/216] START criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/3; 79/216] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.590 total time=   0.2s
# [CV 3/3; 80/216] START criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 3/3; 80/216] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.478 total time=   0.3s
# [CV 1/3; 83/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 1/3; 83/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.614 total time=   0.3s
# [CV 3/3; 84/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 3/3; 84/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.521 total time=   0.6s
# [CV 2/3; 89/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/3; 89/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.604 total time=   0.3s
# [CV 3/3; 91/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 3/3; 91/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.460 total time=   0.2s
# [CV 2/3; 93/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 2/3; 93/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.585 total time=   0.6s
# [CV 2/3; 97/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 2/3; 97/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.623 total time=   0.1s
# [CV 1/3; 99/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 1/3; 99/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.595 total time=   0.7s
# [CV 1/3; 103/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 1/3; 103/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.615 total time=   0.2s
# [CV 2/3; 104/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 2/3; 104/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.610 total time=   0.3s
# [CV 3/3; 106/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 106/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.515 total time=   0.2s
# [CV 2/3; 108/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 108/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.598 total time=   0.6s
# [CV 3/3; 112/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/3; 112/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.350 total time=   0.1s
# [CV 2/3; 114/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 2/3; 114/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.442 total time=   0.6s
# [CV 1/3; 118/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 1/3; 118/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.338 total time=   0.2s
# [CV 3/3; 119/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 3/3; 119/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.240 total time=   0.3s
# [CV 3/3; 121/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 3/3; 121/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.270 total time=   0.2s
# [CV 1/3; 123/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 123/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.145 total time=   0.5s
# [CV 3/3; 126/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 126/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.270 total time=   0.5s
# [CV 2/3; 131/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 2/3; 131/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.370 total time=   0.3s
# [CV 3/3; 133/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 133/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.247 total time=   0.2s
# [CV 2/3; 135/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 135/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.293 total time=   0.5s
# [CV 1/3; 139/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 1/3; 139/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.562 total time=   0.2s
# [CV 3/3; 140/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 3/3; 140/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.455 total time=   0.3s
# [CV 3/3; 142/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 3/3; 142/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.437 total time=   0.2s
# [CV 2/3; 144/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 2/3; 144/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.562 total time=   0.6s
# [CV 3/3; 148/216] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 3/3; 148/216] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.432 total time=   0.2s
# [CV 2/3; 150/216] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 2/3; 150/216] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.547 total time=   0.6s
# [CV 2/3; 154/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 2/3; 154/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.542 total time=   0.2s
# [CV 1/3; 156/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 1/3; 156/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.592 total time=   0.6s
# [CV 3/3; 159/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 3/3; 159/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.467 total time=   0.6s
# [CV 2/3; 164/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 2/3; 164/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.585 total time=   0.3s
# [CV 2/3; 166/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/3; 166/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.563 total time=   0.2s
# [CV 2/3; 167/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/3; 167/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.587 total time=   0.4s
# [CV 2/3; 169/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/3; 169/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.610 total time=   0.2s
# [CV 3/3; 170/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/3; 170/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.495 total time=   0.4s
# [CV 1/3; 173/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 1/3; 173/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.602 total time=   0.3s
# [CV 1/3; 175/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 1/3; 175/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.594 total time=   0.2s
# [CV 2/3; 176/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 2/3; 176/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.590 total time=   0.3s
# [CV 3/3; 178/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 3/3; 178/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.495 total time=   0.1s
# [CV 2/3; 180/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 2/3; 180/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.596 total time=   0.5s
# [CV 2/3; 184/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 2/3; 184/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.571 total time=   0.1s
# [CV 1/3; 186/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 1/3; 186/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.590 total time=   0.5s
# [CV 3/3; 189/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 3/3; 189/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.484 total time=   0.5s
# [CV 2/3; 194/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/3; 194/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.604 total time=   0.3s
# [CV 2/3; 196/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/3; 196/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.579 total time=   0.1s
# [CV 3/3; 197/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/3; 197/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.500 total time=   0.3s
# [CV 1/3; 200/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 1/3; 200/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.611 total time=   0.3s
# [CV 3/3; 201/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 3/3; 201/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.511 total time=   0.5s
# [CV 1/3; 207/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 1/3; 207/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.619 total time=   0.5s
# [CV 3/3; 210/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 3/3; 210/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.479 total time=   0.5s
# [CV 3/3; 215/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 3/3; 215/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.489 total time=   0.3s
# [CV 2/3; 1/10] START learning_rate=0.0001, n_estimators=2000....................
# [CV 2/3; 1/10] END learning_rate=0.0001, n_estimators=2000;, score=0.571 total time=   5.8s
# [CV 2/3; 4/10] START learning_rate=0.01, n_estimators=5000......................
# [CV 2/3; 4/10] END learning_rate=0.01, n_estimators=5000;, score=0.655 total time=  15.4s
# [CV 3/3; 7/10] START learning_rate=1, n_estimators=2000.........................
# [CV 3/3; 7/10] END learning_rate=1, n_estimators=2000;, score=0.522 total time=   5.8s
# [CV 2/3; 9/10] START learning_rate=10, n_estimators=2000........................
# [CV 2/3; 9/10] END learning_rate=10, n_estimators=2000;, score=0.306 total time=   6.2s
# [CV 3/3; 2/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 3/3; 2/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.289 total time=   0.3s
# [CV 1/3; 5/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 1/3; 5/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.062 total time=   0.3s
# [CV 3/3; 6/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 3/3; 6/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.031 total time=   0.6s
# [CV 3/3; 11/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 3/3; 11/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.270 total time=   0.3s
# [CV 3/3; 13/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 3/3; 13/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.197 total time=   0.1s
# [CV 1/3; 15/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 15/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.062 total time=   0.5s
# [CV 1/3; 19/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 1/3; 19/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.091 total time=   0.1s
# [CV 2/3; 20/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 20/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.289 total time=   0.3s
# [CV 3/3; 22/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/3; 22/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.304 total time=   0.2s
# [CV 2/3; 24/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 2/3; 24/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.243 total time=   0.7s
# [CV 2/3; 28/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 2/3; 28/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.566 total time=   0.2s
# [CV 1/3; 30/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 1/3; 30/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.586 total time=   0.7s
# [CV 1/3; 35/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 1/3; 35/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.483 total time=   0.3s
# [CV 1/3; 37/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 1/3; 37/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.547 total time=   0.1s
# [CV 2/3; 38/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 2/3; 38/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.532 total time=   0.3s
# [CV 3/3; 40/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 3/3; 40/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.455 total time=   0.2s
# [CV 1/3; 42/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 42/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.532 total time=   0.7s
# [CV 1/3; 46/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 1/3; 46/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.538 total time=   0.2s
# [CV 2/3; 47/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 47/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.577 total time=   0.3s
# [CV 3/3; 49/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/3; 49/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.460 total time=   0.1s
# [CV 2/3; 50/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 2/3; 50/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.577 total time=   0.3s
# [CV 3/3; 52/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 52/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.444 total time=   0.2s
# [CV 2/3; 54/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 54/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.557 total time=   0.7s
# [CV 2/3; 58/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/3; 58/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.583 total time=   0.2s
# [CV 2/3; 59/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/3; 59/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.602 total time=   0.3s
# [CV 3/3; 61/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 3/3; 61/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.489 total time=   0.2s
# [CV 2/3; 63/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 2/3; 63/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.569 total time=   0.6s
# [CV 2/3; 67/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/3; 67/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.560 total time=   0.2s
# [CV 3/3; 68/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/3; 68/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.473 total time=   0.3s
# [CV 1/3; 71/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 1/3; 71/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.583 total time=   0.3s
# [CV 3/3; 72/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 72/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.484 total time=   0.6s
# [CV 1/3; 78/216] START criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 1/3; 78/216] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.588 total time=   0.6s
# [CV 1/3; 82/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 1/3; 82/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.649 total time=   0.2s
# [CV 2/3; 83/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 2/3; 83/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.596 total time=   0.3s
# [CV 3/3; 85/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/3; 85/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.479 total time=   0.1s
# [CV 2/3; 87/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 2/3; 87/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.610 total time=   0.6s
# [CV 2/3; 91/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 91/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.611 total time=   0.2s
# [CV 3/3; 92/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 3/3; 92/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.505 total time=   0.3s
# [CV 1/3; 95/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 1/3; 95/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.595 total time=   0.3s
# [CV 3/3; 96/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 96/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.521 total time=   0.6s
# [CV 3/3; 101/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 3/3; 101/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.521 total time=   0.3s
# [CV 1/3; 104/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 1/3; 104/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.611 total time=   0.3s
# [CV 1/3; 106/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 1/3; 106/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.624 total time=   0.2s
# [CV 2/3; 107/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 2/3; 107/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.604 total time=   0.3s
# [CV 3/3; 109/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 3/3; 109/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.361 total time=   0.2s
# [CV 2/3; 111/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 2/3; 111/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.366 total time=   0.6s
# [CV 2/3; 115/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/3; 115/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.405 total time=   0.1s
# [CV 3/3; 116/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/3; 116/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.197 total time=   0.3s
# [CV 1/3; 119/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 1/3; 119/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.090 total time=   0.3s
# [CV 3/3; 120/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 3/3; 120/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.222 total time=   0.6s
# [CV 2/3; 125/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 125/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.293 total time=   0.3s
# [CV 2/3; 127/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 2/3; 127/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.354 total time=   0.1s
# [CV 1/3; 129/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 1/3; 129/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.091 total time=   0.5s
# [CV 2/3; 133/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 2/3; 133/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.370 total time=   0.2s
# [CV 3/3; 134/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 3/3; 134/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.400 total time=   0.3s
# [CV 1/3; 137/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 1/3; 137/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.604 total time=   0.3s
# [CV 2/3; 139/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 2/3; 139/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.542 total time=   0.2s
# [CV 1/3; 141/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 1/3; 141/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.542 total time=   0.6s
# [CV 1/3; 145/216] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 1/3; 145/216] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.577 total time=   0.2s
# [CV 2/3; 146/216] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 2/3; 146/216] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.557 total time=   0.3s
# [CV 2/3; 148/216] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/3; 148/216] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.516 total time=   0.2s
# [CV 1/3; 150/216] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 150/216] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.547 total time=   0.6s
# [CV 1/3; 154/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 1/3; 154/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.532 total time=   0.2s
# [CV 2/3; 155/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 155/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.562 total time=   0.3s
# [CV 3/3; 157/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/3; 157/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.478 total time=   0.2s
# [CV 2/3; 159/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 2/3; 159/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.557 total time=   0.7s
# [CV 3/3; 163/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 3/3; 163/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.495 total time=   0.2s
# [CV 2/3; 165/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 2/3; 165/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.590 total time=   0.8s
# [CV 3/3; 169/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 3/3; 169/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.449 total time=   0.2s
# [CV 2/3; 171/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 2/3; 171/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.590 total time=   0.7s
# [CV 2/3; 175/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/3; 175/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.544 total time=   0.2s
# [CV 1/3; 177/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 177/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.602 total time=   0.6s
# [CV 1/3; 181/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 1/3; 181/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.624 total time=   0.2s
# [CV 2/3; 182/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 2/3; 182/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.585 total time=   0.3s
# [CV 2/3; 185/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 2/3; 185/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.602 total time=   0.3s
# [CV 1/3; 188/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 1/3; 188/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.604 total time=   0.3s
# [CV 1/3; 190/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 1/3; 190/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.629 total time=   0.1s
# [CV 2/3; 191/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 2/3; 191/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.630 total time=   0.3s
# [CV 3/3; 193/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/3; 193/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.463 total time=   0.1s
# [CV 1/3; 195/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 1/3; 195/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.623 total time=   0.5s
# [CV 2/3; 199/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 199/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.611 total time=   0.1s
# [CV 3/3; 200/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 3/3; 200/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.505 total time=   0.3s
# [CV 1/3; 203/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 1/3; 203/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.619 total time=   0.3s
# [CV 3/3; 204/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 204/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.505 total time=   0.5s
# [CV 3/3; 209/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 3/3; 209/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.489 total time=   0.3s
# [CV 1/3; 212/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 1/3; 212/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.623 total time=   0.3s
# [CV 3/3; 213/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 3/3; 213/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.468 total time=   0.5s
# [CV 1/3; 3/10] START learning_rate=0.01, n_estimators=2000......................
# [CV 1/3; 3/10] END learning_rate=0.01, n_estimators=2000;, score=0.625 total time=   5.8s
# [CV 1/3; 5/10] START learning_rate=0.1, n_estimators=2000.......................
# [CV 1/3; 5/10] END learning_rate=0.1, n_estimators=2000;, score=0.656 total time=   6.6s
# [CV 3/3; 5/10] START learning_rate=0.1, n_estimators=2000.......................
# [CV 3/3; 5/10] END learning_rate=0.1, n_estimators=2000;, score=0.532 total time=   6.0s
# [CV 2/3; 7/10] START learning_rate=1, n_estimators=2000.........................
# [CV 2/3; 7/10] END learning_rate=1, n_estimators=2000;, score=0.555 total time=   5.7s
# [CV 1/3; 9/10] START learning_rate=10, n_estimators=2000........................
# [CV 1/3; 9/10] END learning_rate=10, n_estimators=2000;, score=0.170 total time=   5.0s
# [CV 3/3; 9/10] START learning_rate=10, n_estimators=2000........................
# [CV 3/3; 9/10] END learning_rate=10, n_estimators=2000;, score=0.356 total time=   6.6s
# [CV 1/3; 3/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 1/3; 3/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.119 total time=   0.7s
# [CV 2/3; 7/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 2/3; 7/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.437 total time=   0.2s
# [CV 1/3; 9/216] START criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 1/3; 9/216] END criterion=entropy, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.062 total time=   0.6s
# [CV 1/3; 13/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 1/3; 13/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.316 total time=   0.1s
# [CV 3/3; 14/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 3/3; 14/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.293 total time=   0.2s
# [CV 1/3; 17/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 1/3; 17/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.000 total time=   0.3s
# [CV 3/3; 18/216] START criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 3/3; 18/216] END criterion=entropy, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.316 total time=   0.6s
# [CV 1/3; 24/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 1/3; 24/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.031 total time=   0.6s
# [CV 3/3; 27/216] START criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 3/3; 27/216] END criterion=entropy, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.197 total time=   0.6s
# [CV 2/3; 32/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 2/3; 32/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.547 total time=   0.3s
# [CV 1/3; 34/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/3; 34/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.539 total time=   0.2s
# [CV 3/3; 35/216] START criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 3/3; 35/216] END criterion=entropy, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.449 total time=   0.3s
# [CV 3/3; 37/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 3/3; 37/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.477 total time=   0.1s
# [CV 2/3; 39/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 2/3; 39/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.516 total time=   0.6s
# [CV 1/3; 43/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 43/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.547 total time=   0.2s
# [CV 3/3; 44/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 3/3; 44/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.442 total time=   0.3s
# ...
# [CV 1/3; 39/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.542 total time=   0.6s
# [CV 3/3; 42/216] START criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 42/216] END criterion=entropy, max_depth=2, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.449 total time=   0.7s
# [CV 2/3; 48/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 2/3; 48/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.516 total time=   0.7s
# [CV 2/3; 52/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 2/3; 52/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.505 total time=   0.2s
# [CV 1/3; 54/216] START criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 1/3; 54/216] END criterion=entropy, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.489 total time=   0.7s
# [CV 1/3; 58/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 1/3; 58/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.582 total time=   0.3s
# [CV 2/3; 60/216] START criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 2/3; 60/216] END criterion=entropy, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.590 total time=   0.6s
# [CV 3/3; 64/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 3/3; 64/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.516 total time=   0.2s
# [CV 2/3; 66/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 2/3; 66/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.602 total time=   0.6s
# [CV 1/3; 70/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 70/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.566 total time=   0.2s
# [CV 3/3; 71/216] START criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 3/3; 71/216] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.484 total time=   0.3s
# [CV 1/3; 74/216] START criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 1/3; 74/216] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.594 total time=   0.3s
# [CV 3/3; 75/216] START criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 3/3; 75/216] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.484 total time=   0.6s
# [CV 2/3; 80/216] START criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=100
# [CV 2/3; 80/216] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.574 total time=   0.3s
# [CV 3/3; 82/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 3/3; 82/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.505 total time=   0.2s
# [CV 2/3; 84/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 2/3; 84/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.604 total time=   0.6s
# [CV 3/3; 88/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 3/3; 88/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.433 total time=   0.2s
# [CV 2/3; 90/216] START criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 2/3; 90/216] END criterion=entropy, max_depth=4, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.610 total time=   0.7s
# [CV 2/3; 94/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=50
# [CV 2/3; 94/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.617 total time=   0.2s
# [CV 1/3; 96/216] START criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 1/3; 96/216] END criterion=entropy, max_depth=4, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.632 total time=   0.6s
# [CV 2/3; 100/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 2/3; 100/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.598 total time=   0.2s
# [CV 1/3; 102/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 1/3; 102/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.611 total time=   0.7s
# [CV 3/3; 105/216] START criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 3/3; 105/216] END criterion=entropy, max_depth=4, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.505 total time=   0.6s
# [CV 1/3; 111/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 1/3; 111/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.091 total time=   0.6s
# [CV 1/3; 115/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50
# [CV 1/3; 115/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.289 total time=   0.1s
# [CV 2/3; 116/216] START criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# [CV 2/3; 116/216] END criterion=gini, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.263 total time=   0.3s
# [CV 3/3; 118/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 3/3; 118/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.350 total time=   0.2s
# [CV 2/3; 120/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 2/3; 120/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.312 total time=   0.6s
# [CV 2/3; 124/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 2/3; 124/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.308 total time=   0.1s
# [CV 1/3; 126/216] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# [CV 1/3; 126/216] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, n_estimators=200;, score=0.222 total time=   0.5s
# [CV 3/3; 129/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 3/3; 129/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.222 total time=   0.6s
# [CV 1/3; 135/216] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 1/3; 135/216] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.091 total time=   0.6s
# [CV 3/3; 138/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200
# [CV 3/3; 138/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.455 total time=   0.6s
# [CV 1/3; 144/216] START criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 1/3; 144/216] END criterion=gini, max_depth=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.562 total time=   0.6s
# [CV 3/3; 147/216] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 3/3; 147/216] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.472 total time=   0.6s
# [CV 3/3; 152/216] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 3/3; 152/216] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.467 total time=   0.3s
# [CV 1/3; 155/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 1/3; 155/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.562 total time=   0.3s
# [CV 1/3; 157/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 1/3; 157/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.553 total time=   0.2s
# [CV 3/3; 158/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100
# [CV 3/3; 158/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=0.462 total time=   0.3s
# [CV 3/3; 160/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 160/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.462 total time=   0.2s
# [CV 2/3; 162/216] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 162/216] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.562 total time=   0.7s
# [CV 3/3; 166/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50
# [CV 3/3; 166/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.505 total time=   0.2s
# [CV 2/3; 168/216] START criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 2/3; 168/216] END criterion=gini, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.596 total time=   0.7s
# [CV 2/3; 172/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50
# [CV 2/3; 172/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=50;, score=0.585 total time=   0.2s
# [CV 3/3; 173/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=100
# [CV 3/3; 173/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.478 total time=   0.3s
# [CV 1/3; 176/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100
# [CV 1/3; 176/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=100;, score=0.574 total time=   0.3s
# [CV 3/3; 177/216] START criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=200
# [CV 3/3; 177/216] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=5, n_estimators=200;, score=0.473 total time=   0.5s
# [CV 3/3; 182/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=100
# [CV 3/3; 182/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.484 total time=   0.3s
# [CV 3/3; 184/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=50
# [CV 3/3; 184/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.495 total time=   0.1s
# [CV 2/3; 186/216] START criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=200
# [CV 2/3; 186/216] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=5, n_estimators=200;, score=0.590 total time=   0.5s
# [CV 2/3; 190/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=50
# [CV 2/3; 190/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.624 total time=   0.1s
# [CV 3/3; 191/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=100
# [CV 3/3; 191/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.525 total time=   0.3s
# [CV 1/3; 194/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=100
# [CV 1/3; 194/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.624 total time=   0.3s
# [CV 3/3; 195/216] START criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200
# [CV 3/3; 195/216] END criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.521 total time=   0.5s
# [CV 1/3; 201/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200
# [CV 1/3; 201/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.582 total time=   0.5s
# [CV 1/3; 205/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50
# [CV 1/3; 205/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.602 total time=   0.1s
# [CV 2/3; 206/216] START criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# [CV 2/3; 206/216] END criterion=gini, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=100;, score=0.630 total time=   0.3s
# [CV 3/3; 208/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50
# [CV 3/3; 208/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.515 total time=   0.1s
# [CV 2/3; 210/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200
# [CV 2/3; 210/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.598 total time=   0.5s
# [CV 3/3; 214/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50
# [CV 3/3; 214/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.511 total time=   0.1s
# [CV 2/3; 216/216] START criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200
# [CV 2/3; 216/216] END criterion=gini, max_depth=4, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.617 total time=   0.4s
# [CV 3/3; 2/10] START learning_rate=0.0001, n_estimators=5000....................
# [CV 3/3; 2/10] END learning_rate=0.0001, n_estimators=5000;, score=0.500 total time=  15.6s
# [CV 3/3; 6/10] START learning_rate=0.1, n_estimators=5000.......................
# [CV 3/3; 6/10] END learning_rate=0.1, n_estimators=5000;, score=0.513 total time=  14.6s
# [CV 3/3; 10/10] START learning_rate=10, n_estimators=5000.......................
# [CV 3/3; 10/10] END learning_rate=10, n_estimators=5000;, score=0.356 total time=  11.2s

# %% [markdown]
# ### One final word: remember, Bagging and Boosting methods are not restricted to trees for weak learners!
